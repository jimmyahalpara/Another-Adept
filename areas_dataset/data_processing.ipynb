# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('Pincode_30052019.csv')
df
# Out:
#                   Circle Name          Region Name       Division Name  \
# 0       Andhra Pradesh Circle       Kurnool Region  Anantapur Division
# 1       Andhra Pradesh Circle       Kurnool Region  Anantapur Division
# 2       Andhra Pradesh Circle       Kurnool Region  Anantapur Division
# 3       Andhra Pradesh Circle       Kurnool Region  Anantapur Division
# 4       Andhra Pradesh Circle       Kurnool Region  Anantapur Division
# ...                       ...                  ...                 ...
# 155594     West Bengal Circle  South Bengal Region     Tamluk Division
# 155595     West Bengal Circle  South Bengal Region     Tamluk Division
# 155596     West Bengal Circle  South Bengal Region     Tamluk Division
# 155597     West Bengal Circle  South Bengal Region     Tamluk Division
# 155598     West Bengal Circle  South Bengal Region     Tamluk Division
#
#                 Office Name  Pincode OfficeType  Delivery        District  \
# 0       A Narayanapuram B.O   515004         BO  Delivery      ANANTHAPUR
# 1               Akuledu B.O   515731         BO  Delivery      ANANTHAPUR
# 2               Alamuru B.O   515002         BO  Delivery      ANANTHAPUR
# 3             Allapuram B.O   515766         BO  Delivery      ANANTHAPUR
# 4                 Aluru B.O   515415         BO  Delivery      ANANTHAPUR
# ...                     ...      ...        ...       ...             ...
# 155594  Uttar Sautanchak BO   721649         BO  Delivery  EAST MIDNAPORE
# 155595       Uttarjianda BO   721151         BO  Delivery  EAST MIDNAPORE
# 155596     Uttarkotebarh BO   721626         BO  Delivery  EAST MIDNAPORE
# 155597    Uttarmechogram BO   721139         BO  Delivery  EAST MIDNAPORE
# 155598      Uttarsonamui BO   721648         BO  Delivery  EAST MIDNAPORE
#
#              StateName
# 0       Andhra Pradesh
# 1       Andhra Pradesh
# 2       Andhra Pradesh
# 3       Andhra Pradesh
# 4       Andhra Pradesh
# ...                ...
# 155594     West Bengal
# 155595     West Bengal
# 155596     West Bengal
# 155597     West Bengal
# 155598     West Bengal
#
# [155599 rows x 9 columns]

# %%
df_test = df[['Office Name', 'District', 'StateName']].copy()
df_test
# Out:
#                 Office Name        District       StateName
# 0       A Narayanapuram B.O      ANANTHAPUR  Andhra Pradesh
# 1               Akuledu B.O      ANANTHAPUR  Andhra Pradesh
# 2               Alamuru B.O      ANANTHAPUR  Andhra Pradesh
# 3             Allapuram B.O      ANANTHAPUR  Andhra Pradesh
# 4                 Aluru B.O      ANANTHAPUR  Andhra Pradesh
# ...                     ...             ...             ...
# 155594  Uttar Sautanchak BO  EAST MIDNAPORE     West Bengal
# 155595       Uttarjianda BO  EAST MIDNAPORE     West Bengal
# 155596     Uttarkotebarh BO  EAST MIDNAPORE     West Bengal
# 155597    Uttarmechogram BO  EAST MIDNAPORE     West Bengal
# 155598      Uttarsonamui BO  EAST MIDNAPORE     West Bengal
#
# [155599 rows x 3 columns]

# %%
df_test['Office Name'] = df_test['Office Name'].str.replace('BO', '')
df_test['Office Name'] = df_test['Office Name'].str.replace('B.O', '')
df_test['Office Name'] = df_test['Office Name'].str.replace('S.O', '')
df_test['Office Name'] = df_test['Office Name'].str.replace('SO', '')
# Out:
# <ipython-input-5-490c3af380a7>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_test['Office Name'] = df_test['Office Name'].str.replace('B.O', '')
# <ipython-input-5-490c3af380a7>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_test['Office Name'] = df_test['Office Name'].str.replace('S.O', '')

# %%
df_test.columns = ['area', 'city', 'state']

# %%
df_city = df_test[['city', 'state']].copy()

# %%
df_city = df_city.drop_duplicates()
df_city = df_city.reset_index(drop=True)
df_city = df_city.reset_index()

# %%
df_city['index'] += 1

# %%
df_city.to_csv('cities.csv', columns = ['index', 'city', 'state'], index = False)

# %%
df_city = df_city.set_index('city')

# %%
df_city_dict = df_city['index'].to_dict()

# %%
df_city_dict
# Out:
# {'ANANTHAPUR': 1,
#  'Chittoor': 2,
#  'Madanapalle': 3,
#  'KADAPA': 4,
#  'Ananthapur': 5,
#  'Hindupur': 6,
#  'Dharmavaram': 7,
#  'ANANTAPUR': 8,
#  'Kurnool': 9,
#  'KURNOOL': 10,
#  'PRAKASAM': 11,
#  'Prakasam': 12,
#  'CHITTOOR': 13,
#  'West Godavari': 14,
#  'WEST GODAVARI': 28,
#  'Palakol': 16,
#  'VIZIANAGARAM': 39,
#  'KRISHNA': 18,
#  'Krishna': 19,
#  'NELLORE': 20,
#  'Guntur': 21,
#  'GUNTUR': 22,
#  'Machilipatnam': 23,
#  'Avanigadda': 24,
#  'Nellore': 25,
#  'Warangal': 791,
#  'Kovvur': 27,
#  'Tadepalligudem': 29,
#  'East Godavari': 30,
#  'Bapatla': 31,
#  'Karim Nagar': 32,
#  'AMLAPURAM': 33,
#  'VISAKHAPATNAM': 34,
#  'Visakhapatnam': 35,
#  'EAST GODAVARI': 36,
#  'YANAM': 37,
#  'SRIKAKULAM': 38,
#  'Bhadrachalam': 40,
#  'Srikalahasti': 41,
#  'Bhongir': 42,
#  'KARIMGANJ': 43,
#  'HAILAKANDI': 44,
#  'CACHAR': 45,
#  'DIMA HASSO - NORTH CACHAR HILL': 46,
#  'KARBI ANGLONG': 47,
#  'UDALGURI': 48,
#  'SONITPUR': 49,
#  'DARRANG': 50,
#  'BONGAIGAON': 51,
#  'KOKRAJHAR': 52,
#  'GOALPARA': 53,
#  'DHUBRI': 54,
#  'Dhubri': 55,
#  'KAMRUP': 56,
#  'KAMRUP METROPOLITAN': 57,
#  'BAKSA': 58,
#  'NALBARI': 59,
#  'BARPETA': 60,
#  'Barpeta': 61,
#  'LAKHIMPUR': 62,
#  'DIBRUGARH': 63,
#  'DHEMAJI': 64,
#  'Sonapur': 65,
#  'MARIGAON': 66,
#  'NAGAON': 67,
#  'SIBSAGAR': 68,
#  'GOLAGHAT': 69,
#  'JORHAT': 70,
#  'TINSUKIA': 71,
#  'GAYA': 72,
#  'AURANGABAD': 490,
#  'ARWAL': 74,
#  'AURANAGABAD': 76,
#  'BHOJPUR': 77,
#  'BUXAR': 78,
#  'JEHANABAD': 79,
#  'KAIMUR BHABUA': 80,
#  'PATNA': 81,
#  'JAMUI': 82,
#  'Patna': 83,
#  'EAST CHAMPARAN': 84,
#  'PURNIA': 85,
#  'ROHTAS': 86,
#  'VAISHALI': 87,
#  'SAMASTIPUR': 88,
#  'BEGUSARAI': 89,
#  'KHAGARIA': 90,
#  'Khagaria': 91,
#  'KATIHAR': 92,
#  'BHAGALPUR': 93,
#  'BANKA': 96,
#  'DEOGHAR': 336,
#  'KISHANGANJ': 97,
#  'LAKHISARAI': 98,
#  'MUNGER': 99,
#  'SHEIKHPURA': 100,
#  'NALANDA': 101,
#  'Nalanda': 102,
#  'NAWADA': 103,
#  'Sheikhpura': 104,
#  'SHEOHAR': 105,
#  'MADHEPURA': 106,
#  'SUPAUL': 107,
#  'SAHARSA': 108,
#  'DARBHANGA': 121,
#  'MUZAFFARPUR': 110,
#  'SITAMARHI': 113,
#  'MADHUBANI': 115,
#  nan: 617,
#  'WEST CHAMPARAN': 123,
#  'ARARIA': 124,
#  'SARAN': 125,
#  'GOPALGANJ': 126,
#  'SIWAN': 127,
#  'BILASPURCGH': 128,
#  'JANJGIRCHAMPA': 129,
#  'KORBA': 130,
#  'MUNGELI': 131,
#  'Janjgir-Champa': 132,
#  'DURG': 133,
#  'RAJNANDGAON': 134,
#  'BALOD': 135,
#  'BEMETARA': 136,
#  'KAWARDHA': 137,
#  'RAIGARH': 535,
#  'SURGUJA': 139,
#  'JASPUR': 140,
#  'BALRAMPUR': 889,
#  'KORIYA': 142,
#  'SURAJPUR': 143,
#  'GARIABAND': 144,
#  'MAHASAMUND': 145,
#  'DHAMTARI': 146,
#  'RAIPUR': 147,
#  'BALOD BAZER': 148,
#  'Kanker': 149,
#  'Jagdalpur': 150,
#  'Bastar': 151,
#  'Dantewada': 152,
#  'Bijapur(CGH)': 153,
#  'DANTEWADA': 154,
#  'Bilaspur': 155,
#  'Narayanpur': 156,
#  'SUKMA': 157,
#  'Raigarh': 158,
#  'BASTAR': 159,
#  'Makdi': 160,
#  'KONDAGAON': 161,
#  'BIJAPUR(CGH)': 162,
#  'EAST DELHI': 163,
#  'SHAHDARA': 164,
#  'NORTH EAST DELHI': 165,
#  'NEW DELHI': 166,
#  'NORTH DELHI': 167,
#  'NORTH WEST DELHI': 168,
#  'CENTRAL DELHI': 169,
#  'SOUTH DELHI': 170,
#  'New Delhi': 171,
#  'SOUTH WEST DELHI': 174,
#  'WEST DELHI': 173,
#  'AHMEDABAD': 175,
#  'GANDHI NAGAR': 176,
#  'Ahmedabad City': 177,
#  'BANASKANTHA': 178,
#  'BHARUCH': 179,
#  'BOTAB': 181,
#  'MAHESANA': 182,
#  'Gandhinagar': 183,
#  'PATAN': 184,
#  'SABARKANTHA': 185,
#  'ARAVALLI': 186,
#  'AMRELI': 187,
#  'ANAND': 188,
#  'BHAVNAGAR': 189,
#  'RAJKOT': 190,
#  'JAMNAGAR': 191,
#  'DEVBHOOMI DWERKA': 192,
#  'MORBI': 193,
#  'GIR SOMNATH': 194,
#  'JUNAGADH': 195,
#  'Junagadh': 196,
#  'DIU': 197,
#  'KACHCHH': 198,
#  'PORBANDAR': 199,
#  'Porbandar': 200,
#  'Morbi': 201,
#  'SURENDRA NAGAR': 202,
#  'KHEDA': 203,
#  'MAHISAGAR': 204,
#  'SURAT': 205,
#  'TAPI': 206,
#  'DANGS': 207,
#  'NARMADA': 208,
#  'NAVSARI': 209,
#  'DAHOD': 210,
#  'PANCH MAHALS': 211,
#  'Surat': 212,
#  'VADODARA': 213,
#  'Chhotaudepur': 214,
#  'CHHOTA UDEPUR': 215,
#  'VALSAD': 216,
#  'DADRA  NAGAR HAVELI': 217,
#  'DAMAN': 218,
#  'AMBALA': 219,
#  'YAMUNANAGAR': 220,
#  'PANCHKULA': 221,
#  'Ambala': 222,
#  'Ambala City': 223,
#  'BHIWANI': 225,
#  'Bhiwani': 226,
#  'FARIDABAD': 227,
#  'PALWAL': 228,
#  'MEWAT': 229,
#  'REWARI': 230,
#  'GURGAON': 231,
#  'MAHENDRAGARH': 232,
#  'FATEHABAD': 233,
#  'SIRSA': 234,
#  'HISAR': 235,
#  'KARNAL': 236,
#  'PANIPAT': 237,
#  'JIND': 238,
#  'Panipat': 239,
#  'Jind': 240,
#  'KURUKSHETRA': 241,
#  'KAITHAL': 242,
#  'Kaithal': 243,
#  'Kurukshetra': 244,
#  'JHAJJAR': 263,
#  'ROHTAK': 256,
#  'SONIPAT': 264,
#  'CHAMBA': 265,
#  'KANGRA': 266,
#  'HAMIRPURHP': 267,
#  'BILASPUR HP': 269,
#  'HAMIRPUR(HP)': 270,
#  'BILASPUR (HP)': 271,
#  'MANDI': 272,
#  'KULLU': 273,
#  'LAHUL  SPITI': 274,
#  'KINNAUR': 275,
#  'SHIMLA': 276,
#  'SIRMAUR': 277,
#  'SOLAN': 278,
#  'UNA': 279,
#  'Bandipur': 280,
#  'BANDIPUR': 281,
#  'Kupwara': 282,
#  'BARAMULLA': 283,
#  'Baramulla': 284,
#  'KUPWARA': 285,
#  'KULGAM': 286,
#  'SAMBA': 287,
#  'JAMMU': 288,
#  'KATHUA': 289,
#  'POONCH': 290,
#  'KARGIL': 291,
#  'RAJAURI': 292,
#  'PULWAMA': 293,
#  'BUDGAM': 294,
#  'SRINAGAR': 295,
#  'ANANTHNAG': 296,
#  'GANDERBAL': 297,
#  'SHOPIAN': 340,
#  'REASI': 299,
#  'DODA': 300,
#  'RAMBAN': 301,
#  'UDHAMPUR': 302,
#  'Kargil': 303,
#  'Leh': 304,
#  'DHANBAD': 305,
#  'BOKARO': 306,
#  'Dhanbad': 307,
#  'GIRIDH': 308,
#  'HAZARIBAG': 319,
#  'CHATRA': 310,
#  'Chatra': 311,
#  'Ramgarh': 312,
#  'RAMGARH': 313,
#  'KODERMA': 317,
#  'Koderma': 315,
#  'Hazaribagh': 316,
#  'PALAMAU': 318,
#  'GUMLA': 320,
#  'LATEHAR': 321,
#  'GARHWA': 322,
#  'PAKUR': 323,
#  'RANCHI': 324,
#  'SIMDEGA': 325,
#  'Lohardaga': 326,
#  'KHUNTI': 327,
#  'LOHARDAGA': 328,
#  'Khunti': 329,
#  'Gumla': 330,
#  'Simdega': 331,
#  'WEST SINGHBHUM': 332,
#  'GODDA': 333,
#  'JAMTARA': 334,
#  'SAHIBGANJ': 335,
#  'DUMKA': 337,
#  'SERAIKELAKHARSAWAN': 338,
#  'EAST SINGHBHUM': 339,
#  'BENGALURU': 341,
#  'Bangalore': 342,
#  'BENGALURU RURAL': 343,
#  'Bengaluru': 344,
#  'RAMANAGAR': 345,
#  'Ramdurg': 346,
#  'Ramanagara': 347,
#  'BAGALKOT': 348,
#  'BELLARY': 349,
#  'DAVANGERE': 350,
#  'BALLARI': 351,
#  'BELAGAVI': 352,
#  'Bidar': 353,
#  'BIDAR': 354,
#  'Belgaum': 355,
#  'Hubballi': 356,
#  'Dharwad': 357,
#  'Madikeri': 358,
#  'Arsikere': 359,
#  'Kundgol': 360,
#  'Kalghatgi': 361,
#  'GADAG': 362,
#  'KOPPAL': 363,
#  'Koppal': 364,
#  'DHARWAD': 365,
#  'HAVERI': 366,
#  'Haveri': 367,
#  'KALABURAGI': 368,
#  'YADGIR': 369,
#  'Gulbarga': 370,
#  'UTTARA KANNADA': 371,
#  'RAICHUR': 372,
#  'Uttara Kannada': 373,
#  'Siddapur': 374,
#  'Joida': 375,
#  'BIJAPUR(KAR)': 376,
#  'BIJAPUR': 377,
#  'CHICKMAGALUR': 378,
#  'Chikkamagaluru': 379,
#  'CHITRADURGA': 380,
#  'Davangere': 381,
#  'HASSAN': 382,
#  'Kodagu': 383,
#  'Athani': 384,
#  'Jamkhandi': 385,
#  'Kollegal': 386,
#  'CHIKKABALLAPUR': 387,
#  'KOLAR': 388,
#  'KODAGU': 389,
#  'Kolar': 390,
#  'Mandya': 391,
#  'Dakshina Kannada': 392,
#  'Udupi': 393,
#  'Mysuru': 394,
#  'Saraswathipuram': 395,
#  'Hanagodu': 396,
#  'MYSORE': 397,
#  'Hunsur': 398,
#  'Chamrajnagar': 399,
#  'Bailhongal': 400,
#  'Nanjangud': 401,
#  'KOLLEGAL': 402,
#  'Sagar': 403,
#  'CHAMARAJANAGAR': 404,
#  'DAKSHINA KANNADA': 405,
#  'UDUPI': 406,
#  'SHIVAMOGGA': 407,
#  'Shivamogga': 408,
#  'TUMAKURU': 409,
#  'KOLLAM': 410,
#  'PATHANAMTHITTA': 411,
#  'ALAPPUZHA': 412,
#  'THIRUVANANTHAPURAM': 413,
#  'Thiruvananthapuram': 414,
#  'WAYANAD': 415,
#  'KOZHIKODE': 416,
#  'MALAPPURAM': 417,
#  'KANNUR': 418,
#  'KASARGOD': 419,
#  'Kasaragod': 420,
#  'PALAKKAD': 421,
#  'Thalassery': 422,
#  'MALAPPURM': 423,
#  'MAHE': 424,
#  'ERNAKULAM': 425,
#  'KOTTAYAM': 426,
#  'IDUKKI': 427,
#  'THRISSUR': 428,
#  'Lakshadweep': 429,
#  'Kochi': 430,
#  'LAKSHADWEEP': 431,
#  'Pathanamthitta': 432,
#  'SEONI': 433,
#  'BALAGHAT': 434,
#  'Seoni': 435,
#  'Balaghat': 436,
#  'BHOPAL': 437,
#  'RAISEN': 438,
#  'CHHATARPUR': 439,
#  'TIKAMGARH': 440,
#  'PANNA': 441,
#  'CHHINDWARA': 442,
#  'BETUL': 443,
#  'HOSHANGABAD': 444,
#  'HARDA': 445,
#  'NARSINGHPUR': 446,
#  'Hoshangabad': 447,
#  'SEHORE': 448,
#  'SATNA': 449,
#  'REWA': 450,
#  'DAMOH': 451,
#  'SAGAR': 452,
#  'DATIA': 453,
#  'ANUPPUR': 454,
#  'UMARIA': 455,
#  'SHAHDOL': 456,
#  'SIDHI': 457,
#  'SINGRAULI': 458,
#  'VIDISHA': 459,
#  'ASHOK NAGAR': 460,
#  'SHIVPURI': 461,
#  'GUNA': 462,
#  'GWALIOR': 463,
#  'INDORE': 464,
#  'Indore': 465,
#  'DEWAS': 466,
#  'DHAR': 467,
#  'KATNI': 468,
#  'JABALPUR': 469,
#  'KHANDWA': 470,
#  'KHARGONE': 471,
#  'BARWANI': 472,
#  'BURHANPUR': 473,
#  'NEEMUCH': 474,
#  'MANDSAUR': 475,
#  'Neemuch': 476,
#  'BHIND': 477,
#  'MORENA': 478,
#  'SHEOPUR': 479,
#  'AGAR MALWA': 480,
#  'RATLAM': 481,
#  'JHABUA': 482,
#  'ALIRAJPUR': 483,
#  'RAJGARH': 484,
#  'UJJAIN': 485,
#  'SHAJAPUR': 486,
#  'MANDLA': 487,
#  'DINDORI': 488,
#  'JALNA': 489,
#  'BEED': 491,
#  'Jalgaon': 492,
#  'BHUSAWAL': 493,
#  'DHULE': 494,
#  'NANDURBAR': 495,
#  'JALGAON': 496,
#  'JALGOAN': 497,
#  'NANDED': 498,
#  'LATUR': 499,
#  'OSMANABAD': 500,
#  'HINGOLI': 501,
#  'PARBHANI': 502,
#  'SOUTH GOA': 503,
#  'NORTH GOA': 504,
#  'Kolhapur': 505,
#  'RATNAGIRI': 506,
#  'Ratnagiri': 507,
#  'RAIGARH(MH)': 533,
#  'Sangli': 509,
#  'Miraj': 510,
#  'SINDHUDURG': 511,
#  'MUMBAI': 512,
#  'MUMBAI SUBUEBAN': 513,
#  'AKOLA': 514,
#  'WASHIM': 515,
#  'AMRAVATI': 516,
#  'BULDHANA': 517,
#  'GADCHIROLI': 518,
#  'CHANDRAPUR': 519,
#  'Gadchiroli': 520,
#  'Chandrapur': 521,
#  'Nagpur': 522,
#  'NAGPUR': 523,
#  'GONDIA': 524,
#  'BHANDARA': 525,
#  'WARDHA': 526,
#  'Yavatmal': 527,
#  'Malegaon': 528,
#  'NASHIK': 530,
#  'Nashik': 531,
#  'THANE': 532,
#  'PALGHAR': 534,
#  'AHMED NAGAR': 536,
#  'SOLAPUR': 537,
#  'PUNE': 538,
#  'Pune': 539,
#  'SATARA': 540,
#  'Ahmed Nagar': 541,
#  'Shrirampur': 542,
#  'Imphal West': 543,
#  'Churachandpur': 544,
#  'Thoubal': 545,
#  'Ukhrul': 546,
#  'Tamenglong': 547,
#  'Chandel': 548,
#  'Imphal East': 549,
#  'Bishnupur': 550,
#  'Senapati': 551,
#  'Tengnoupal': 553,
#  'Imphal': 554,
#  'Jiribam': 555,
#  'THANLON': 556,
#  'Aizawl': 557,
#  'Mammit': 558,
#  'Lunglei': 559,
#  'Kolasib': 560,
#  'Lawngtlai': 561,
#  'Champhai': 563,
#  'Saiha': 564,
#  'Serchhip': 565,
#  'Aizawal': 566,
#  'Mamit': 567,
#  'Zunhebotto': 568,
#  'Dimapur': 581,
#  'Wokha': 570,
#  'Phek': 571,
#  'Zunheboto': 572,
#  'Mokokchung': 573,
#  'Kiphire': 574,
#  'Tuensang': 575,
#  'Mon': 576,
#  'Kohima': 577,
#  'Peren': 578,
#  'Longleng': 579,
#  'South Tripura': 582,
#  'West Tripura': 589,
#  'Gomati': 585,
#  'Sepahijala': 587,
#  'Agartala�': 588,
#  'Gomti': 590,
#  'Lower Dibang Valley': 591,
#  'East Siang': 592,
#  'Dibang Valley': 593,
#  'West Siang': 594,
#  'Lohit': 595,
#  'Papum Pare': 596,
#  'Tawang': 597,
#  'West Kameng': 598,
#  'East Kameng': 599,
#  'Lower Subansiri': 600,
#  'Changlang': 601,
#  'Tirap': 602,
#  'Kurung Kumey': 603,
#  'Upper Siang': 604,
#  'Upper Subansiri': 605,
#  'Upper Dibang Valley': 606,
#  'LOWER SUBANSIRI': 608,
#  'PAPUM PARE': 609,
#  'CHANGLANG': 610,
#  'Dhalai': 611,
#  'North Tripura': 612,
#  'Khowai': 613,
#  'Dharmanagar': 614,
#  'West Garo Hills': 615,
#  'Jaintia Hills': 616,
#  'East Khasi Hills': 618,
#  'South Garo Hills': 619,
#  'East Garo Hills': 620,
#  'Ri Bhoi': 621,
#  'Shillong': 622,
#  'West Khasi Hills': 623,
#  'Tura': 624,
#  'West Jaintia Hills': 625,
#  'South West Khasi Hills': 626,
#  'East Jaintia Hills': 627,
#  'KHORDA': 628,
#  'BALESWAR': 629,
#  'BALASORE': 630,
#  'BHADRAK': 631,
#  'KENDUJHAR': 632,
#  'CUTTACK': 633,
#  'JAJAPUR': 634,
#  'KENDRAPARA': 635,
#  'JAGATSINGHAPUR': 636,
#  'Cuttack': 637,
#  'MAYURBHANJ': 638,
#  'NABARANGAPUR': 639,
#  'PURI': 640,
#  'NAYAGARH': 641,
#  'GANJAM': 642,
#  'KANDHAMAL': 643,
#  'GAJAPATI': 644,
#  'KALAHANDI': 645,
#  'NUAPADA': 646,
#  'KORAPUT': 647,
#  'MALKANGIRI': 648,
#  'RAYAGADA': 649,
#  'BOUDH': 650,
#  'Kandhamal': 651,
#  'BALANGIR': 652,
#  'SONAPUR': 653,
#  'ANGUL': 654,
#  'DHENKANAL': 655,
#  'SAMBALPUR': 656,
#  'BARGARH': 657,
#  'JHARSUGUDA': 658,
#  'DEBAGARH': 659,
#  'SUNDERGARH': 660,
#  'ROPAR': 661,
#  'CHANDIGHAR': 663,
#  'MOHALI': 666,
#  'RUPNAGAR': 665,
#  'MOGA': 667,
#  'LUDHIANA': 668,
#  'FATEHGARH SAHIB': 669,
#  'PATIALA': 670,
#  'SANGRUR': 671,
#  'AMRITSAR': 672,
#  'TARN TARAN': 673,
#  'BATHINDA': 674,
#  'MANSA': 675,
#  'BARNALA': 676,
#  'MUKTSAR': 677,
#  'FARIDKOT': 678,
#  'FAZILKA': 679,
#  'FIROZPUR': 680,
#  'Ferozepur': 681,
#  'PATHANKOT': 682,
#  'GURDASPUR': 683,
#  'HOSHIARPUR': 684,
#  'JALANDHAR': 685,
#  'NAWANSHAHR': 686,
#  'KAPURTHALA': 687,
#  'ALWAR': 688,
#  'BANSWARA': 689,
#  'BHARATPUR': 690,
#  'DHOLPUR': 691,
#  'JAIPUR': 692,
#  'Jaipur': 693,
#  'DAUSA': 694,
#  'SAWAI MADHOPUR': 695,
#  'KARAULI': 696,
#  'KOTA': 697,
#  'AJMER': 698,
#  'BHILWARA': 699,
#  'PRATAPGHAR': 700,
#  'CHITTORGARH': 701,
#  'PALI': 702,
#  'DUNGARPUR': 703,
#  'BARAN': 704,
#  'JHALAWAR': 705,
#  'BUNDI': 706,
#  'TONK': 707,
#  'RAJSAMAND': 708,
#  'UDAIPUR': 709,
#  'BARMER': 710,
#  'BIKANER': 711,
#  'CHURU': 712,
#  'JHUJHUNU': 713,
#  'JODHPUR': 714,
#  'JAISALMER': 715,
#  'NAGAUR': 716,
#  'SIKAR': 717,
#  'SIROHI': 718,
#  'JALOR': 719,
#  'SRI GANGANAGAR': 720,
#  'HANUMANGARH': 721,
#  'SRIGANGANAGAR': 722,
#  'CUDDALORE': 723,
#  'VILLUPURAM': 752,
#  'NAGAPATTINAM': 725,
#  'PERAMBALUR': 726,
#  'DHARMAPURI': 727,
#  'KARUR': 728,
#  'TIRUCHIRAPPALLI': 729,
#  'TIRUPPUR': 730,
#  'SIVAGANGA': 731,
#  'PUDUKKOTTAI': 732,
#  'DINDIGUL': 733,
#  'TIRUVARUR': 734,
#  'THANJAVUR': 735,
#  'KARAIKAL': 736,
#  'Nagapattinam': 737,
#  'ARIYALUR': 738,
#  'SALEM': 739,
#  'Ariyalur': 740,
#  'VELLORE': 741,
#  'Chennai': 742,
#  'TIRUVANNAMALAI': 743,
#  'Vellore': 744,
#  'KANCHIPURAM': 745,
#  'Kanchipuram': 746,
#  'CHENNAI': 747,
#  'TIRUVALLUR': 748,
#  'Tiruvallur': 749,
#  'PONDICHERRY': 751,
#  'KANYAKUMARI': 753,
#  'RAMANATHAPURAM': 754,
#  'TUTICORIN': 755,
#  'TIRUNELVELI': 756,
#  'Tirunelveli': 757,
#  'VIRUDHUNAGAR': 758,
#  'MADURAI': 759,
#  'THENI': 760,
#  'COIMBATORE': 761,
#  'KRISHNAGIRI': 762,
#  'ERODE': 763,
#  'NAMAKKAL': 764,
#  'Salem': 765,
#  'Namakkal': 766,
#  'NILGIRIS': 767,
#  'Nilgiris': 768,
#  'HYDERABAD': 769,
#  'RANGAREDDY': 774,
#  'Rangareddy': 771,
#  'Hyderabad': 772,
#  'Ranga Reddy': 773,
#  'SIDDIPET': 775,
#  'MEDAK': 776,
#  'KARIM NAGAR': 777,
#  'Mancherial': 778,
#  'SANGAREDDY': 779,
#  'ZAHEERABAD': 780,
#  'KHAMMAM': 781,
#  'Vikarabad': 782,
#  'Trimulgherry': 783,
#  'NALGONDA': 784,
#  'Secunderabad': 785,
#  'K.V.Rangareddy': 786,
#  'MANCHERIAL': 787,
#  'ADILABAD': 788,
#  'NIRMAL': 789,
#  'WARANGAL': 790,
#  'Parkal': 792,
#  'Hanamkonda': 793,
#  'Jangaon': 794,
#  'JAYASHANKAR': 795,
#  'BHUPALPALLI': 796,
#  'SIRCILLA': 797,
#  'JAGTIAL': 798,
#  'PEDDAPALLI': 799,
#  'KOTHAGUDEM': 800,
#  'KOTHAGUDEM COLLS': 801,
#  'BHADRACHALAM': 802,
#  'MAHABUB NAGAR': 803,
#  'GADWAL': 804,
#  'WANAPARTHY': 805,
#  'VIKARABAD': 806,
#  'Mahabub Nagar': 807,
#  'Gadwal': 808,
#  'BHONGIR': 809,
#  'JANGAON': 810,
#  'NIZAMABAD': 811,
#  'KAMAREDDY': 812,
#  'SURYAPET': 813,
#  'NAGAR KURNOOL': 814,
#  'STN. JADCHERLA': 815,
#  'MAHABUBABAD': 816,
#  'Warangal Rural': 817,
#  'Mahabubabad': 818,
#  'Mahabuababad': 819,
#  'AGRA': 821,
#  'ALIGARH': 822,
#  'HATHRAS': 823,
#  'Aligarh': 824,
#  'BULANDSHAHR': 825,
#  'ALLAHABAD': 826,
#  'GAUTAM BUDDHA NAGAR': 827,
#  'ETAH': 828,
#  'KANSHIRAM NAGAR': 829,
#  'ETAWAH': 830,
#  'AURAIYA': 831,
#  'JHANSI': 832,
#  'JALAUN': 833,
#  'LALITPUR': 834,
#  'HAPUR': 835,
#  'FIROZABAD': 836,
#  'MAINPURI': 837,
#  'FAIZABAD': 838,
#  'RAEBARELI': 839,
#  'MATHURA': 840,
#  'KAUSHAMBI': 841,
#  'Prayagraj Allahabad': 842,
#  'KUSHINAGAR': 843,
#  'GHAZIPUR': 844,
#  'VARANASI': 845,
#  'SONBHADRA': 846,
#  'MIRZAPUR': 847,
#  'PRATAPGARH': 848,
#  'KANPUR DEHAT': 849,
#  'SULTANPUR': 850,
#  'AMETHI': 851,
#  'PILIBHIT': 852,
#  'BAREILLY': 853,
#  'Pilibhit': 854,
#  'BIJNOR': 855,
#  'BUDAUN': 856,
#  'HARDOI': 857,
#  'KHERI': 858,
#  'MEERUT': 859,
#  'BAGPAT': 860,
#  'AMROHA': 861,
#  'SAMBHAL': 862,
#  'RAMPUR': 863,
#  'MORADABAD': 864,
#  'KANPUR NAGAR': 865,
#  'MUZAFFARNAGAR': 866,
#  'SAHARANPUR': 867,
#  'HARIDWAR': 918,
#  'SHAHJAHANPUR': 869,
#  'Shahjahanpur': 870,
#  'SANT RAVIDAS NAGAR': 871,
#  'AZAMGARH': 872,
#  'MAU': 873,
#  'SHRAWASTI': 874,
#  'BAHRAICH': 875,
#  'SIDDHARTHNAGAR': 884,
#  'BASTI': 886,
#  'SANT KABIR NAGAR': 878,
#  'DEORIA': 887,
#  'GONDA': 888,
#  'GORAKHPUR': 890,
#  'MAHARAJGANJ': 891,
#  'MAHRAJGANJ': 892,
#  'Gorakhpur': 893,
#  'Maharajganj': 894,
#  'BANDA': 895,
#  'CHITRAKOOT': 896,
#  'MAHOBA': 897,
#  'HAMIRPUR': 898,
#  'KANNAUJ': 899,
#  'FARRUKHABAD': 900,
#  'FATEHPUR': 901,
#  'UNNAO': 902,
#  'BARABANKI': 903,
#  'AMBEDKAR NAGAR': 904,
#  'GHAZIABAD': 905,
#  'LUCKNOW': 906,
#  'Lucknow': 907,
#  'SITAPUR': 908,
#  'BALLIA': 910,
#  'JAUNPUR': 911,
#  'CHANDAULI': 912,
#  'Varanasi': 913,
#  'ALMORA': 914,
#  'BAGESHWAR': 915,
#  'CHAMOLI': 916,
#  'RUDRAPRAYAG': 917,
#  'DEHRADUN': 919,
#  'NAINITAL': 920,
#  'CHAMPAWAT': 921,
#  'UDHAM SINGH NAGAR': 922,
#  'PAURI GARHWAL': 923,
#  'PITHORAGARH': 924,
#  'TEHRI GARHWAL': 925,
#  'UTTARKASHI': 926,
#  'EAST SIKKIM': 930,
#  'WEST SIKKIM': 928,
#  'SOUTH SIKKIM': 933,
#  'NORTH SIKKIM': 932,
#  'South Andaman': 934,
#  'North And Middle Andaman': 935,
#  'Nicobar': 936,
#  'Port Blair': 937,
#  'North & Middle Andaman': 938,
#  'Kolkata': 939,
#  'NORTH 24 PARGANAS': 940,
#  'BIRBHUM': 941,
#  'KOLKATA': 948,
#  'SOUTH 24 PARGANAS': 943,
#  'North 24 Parganas': 944,
#  'MURSHIDABAD': 945,
#  'MEDINIPUR': 946,
#  'NADIA': 947,
#  'COOCH BEHAR': 949,
#  'JALPAIGURI': 950,
#  'DARJILING': 951,
#  'EAST MIDNAPORE': 952,
#  'Darjeeling': 953,
#  'Kalimpong': 954,
#  'WEST MIDNAPORE': 955,
#  'SOUTH DINAJPUR': 956,
#  'NORTH DINAJPUR': 957,
#  'MALDA': 958,
#  'BARDHAMAN': 959,
#  'Paschim Bardhaman': 960,
#  'BANKURA': 961,
#  'Bankura': 962,
#  'HOOGHLY': 963,
#  'HOWRAH': 964,
#  'PURULIYA': 965}

# %%
df_test['city'] = df_test['city'].replace(df_city_dict)

# %%
df_test = df_test.reset_index(drop = True)
df_test.index += 1

# %%
df_test[['area', 'city']].to_csv('areas.csv', index_label='index')
